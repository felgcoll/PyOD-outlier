# %%
import io
import os
import pandas as pd

# %%
#Función para crear las columnas que van a enumerar el DF
def columns():
    col = []
    
    for i in range(1,9):
        col.append('x'+str(i))
        col.append('y'+str(i))
        col.append('z'+str(i))
    
    return col

# %%
#Directorio a recorrer
path_csv = '/home/bryan/Escritorio/PyOD/Dataset/'

def Ficheros(path, formato):
    contenido = os.listdir(path)

    #Acumulador del nombre de las   imagenes a utilizar
    archivos = []

    #Se recorre el path para obtener los nombre y se los aggrega al acumulador, en este caso la lista
    for fichero in contenido:
        if os.path.isfile(os.path.join(path, fichero)) and fichero.endswith(formato):
            archivos.append(fichero)
            
    return archivos


#Verificar si obtiene los archivos
print(len(Ficheros(path_csv, '.csv')))
# Out:
# 100

# %%
sampleo = '/home/bryan/Escritorio/PyOD/Dataset/'
dataset = Ficheros(path_csv, '.csv')

# %%
prueba_1 = []
prueba_2 = []
prueba_3 = []

for archivo in dataset:
    if archivo.startswith('1_1'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_2'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_3'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_4'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_5'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_6'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_7'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_8'):
        prueba_2.append(archivo)
    
    elif archivo.startswith('1_9'):
        prueba_3.append(archivo)
        

    

prueba_1.sort()
prueba_2.sort()
prueba_3.sort()

# %%
prueba_1
# Out:
# ['1_10_05A.csv',
#  '1_10_1A.csv',
#  '1_10_2A.csv',
#  '1_10_3A.csv',
#  '1_1_05A.csv',
#  '1_1_1A.csv',
#  '1_1_2A.csv',
#  '1_1_3A.csv',
#  '1_2_05A.csv',
#  '1_2_1A.csv',
#  '1_2_2A.csv',
#  '1_2_3A.csv',
#  '1_3_05A.csv',
#  '1_3_1A.csv',
#  '1_3_2A.csv',
#  '1_3_3A.csv',
#  '1_4_05A.csv',
#  '1_4_1A.csv',
#  '1_4_2A.csv',
#  '1_4_3A.csv',
#  '1_5_05A.csv',
#  '1_5_1A.csv',
#  '1_5_2A.csv',
#  '1_5_3A.csv',
#  '1_6_05A.csv',
#  '1_6_1A.csv',
#  '1_6_2A.csv',
#  '1_6_3A.csv',
#  '1_7_05A.csv',
#  '1_7_1A.csv',
#  '1_7_2A.csv',
#  '1_7_3A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1 = dataframe_chipeado(prueba_1)

base_2 = dataframe_chipeado(prueba_2)

base_3 = dataframe_chipeado(prueba_3)

# %%
base_1.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000213  0.000274  0.000279  0.000146  0.000231  0.000176  0.000063
# 1  0.000106  0.000244  0.000210  0.000159  0.000198  0.000162  0.000147
# 2  0.000150  0.000293  0.000236  0.000161  0.000249  0.000164  0.000097
# 3  0.000122  0.000237  0.000172  0.000147  0.000209  0.000181  0.000089
# 4  0.000168  0.000270  0.000215  0.000173  0.000249  0.000181  0.000088
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000208  0.000323  0.000154  ...  0.000395  0.000267  0.000030  0.000054
# 1  0.000169  0.000288  0.000142  ...  0.000338  0.000171  0.000031  0.000055
# 2  0.000180  0.000276  0.000160  ...  0.000406  0.000247  0.000011  0.000083
# 3  0.000203  0.000292  0.000157  ...  0.000390  0.000154  0.000016  0.000058
# 4  0.000180  0.000320  0.000149  ...  0.000382  0.000240  0.000050  0.000079
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
base_2.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000150  0.000248  0.000183  0.000105  0.000160  0.000133  0.000055
# 1  0.000177  0.000308  0.000227  0.000135  0.000235  0.000157  0.000135
# 2  0.000182  0.000276  0.000252  0.000128  0.000197  0.000164  0.000091
# 3  0.000204  0.000290  0.000251  0.000174  0.000265  0.000242  0.000157
# 4  0.000189  0.000267  0.000244  0.000164  0.000238  0.000114  0.000057
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000174  0.000331  0.000140  ...  0.000388  0.000217 -0.000010  0.000114
# 1  0.000216  0.000328  0.000117  ...  0.000348  0.000226  0.000013  0.000108
# 2  0.000166  0.000279  0.000131  ...  0.000426  0.000242  0.000015  0.000053
# 3  0.000237  0.000282  0.000125  ...  0.000398  0.000253  0.000042  0.000085
# 4  0.000173  0.000325  0.000133  ...  0.000389  0.000255  0.000037  0.000062
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
base_3.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000180  0.000258  0.000236  0.000162  0.000213  0.000211  0.000139
# 1  0.000131  0.000279  0.000214  0.000079  0.000178  0.000131  0.000100
# 2  0.000205  0.000228  0.000238  0.000174  0.000228  0.000183  0.000139
# 3  0.000152  0.000221  0.000197  0.000133  0.000189  0.000109  0.000077
# 4  0.000174  0.000284  0.000277  0.000130  0.000169  0.000147  0.000138
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000207  0.000330  0.000144  ...  0.000405  0.000261  0.000039  0.000066
# 1  0.000172  0.000315  0.000149  ...  0.000383  0.000169  0.000028  0.000080
# 2  0.000205  0.000330  0.000111  ...  0.000397  0.000234  0.000020  0.000093
# 3  0.000164  0.000312  0.000155  ...  0.000431  0.000211  0.000028  0.000068
# 4  0.000209  0.000326  0.000128  ...  0.000386  0.000222  0.000017  0.000093
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
len(base_1), len(base_2), len(base_3)
# Out:
# (528544, 66068, 66068)

# %%
#sampleo2 = '/home/bryan/Escritorio/Paper/Sampleo Final/'

# %%
#base_1.to_csv(sampleo2 + 'TRAINx05.csv')

# %%
prueba_1x = []
prueba_2x = []
prueba_3x = []

for archivo in dataset:
    if archivo.startswith('2_'):
        prueba_1x.append(archivo)
        
    elif archivo.startswith('3_'):
        prueba_2x.append(archivo)
    
    elif archivo.startswith('4_'):
        prueba_3x.append(archivo)

    
prueba_1x.sort()
prueba_2x.sort()
prueba_3x.sort()

# %%
prueba_1x
# Out:
# ['2_1_05A.csv',
#  '2_1_1A.csv',
#  '2_1_2A.csv',
#  '2_1_3A.csv',
#  '2_2_05A.csv',
#  '2_2_1A.csv',
#  '2_2_2A.csv',
#  '2_2_3A.csv',
#  '2_3_05A.csv',
#  '2_3_1A.csv',
#  '2_3_2A.csv',
#  '2_3_3A.csv',
#  '2_4_05A.csv',
#  '2_4_1A.csv',
#  '2_4_2A.csv',
#  '2_4_3A.csv',
#  '2_5_05A.csv',
#  '2_5_1A.csv',
#  '2_5_2A.csv',
#  '2_5_3A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1x = dataframe_chipeado(prueba_1x)

base_2x = dataframe_chipeado(prueba_2x)

base_3x = dataframe_chipeado(prueba_3x)

# %%
base_1x.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000164  0.000302  0.000252  0.000152  0.000214  0.000189  0.000099
# 1  0.000199  0.000293  0.000254  0.000132  0.000236  0.000250  0.000111
# 2  0.000169  0.000232  0.000218  0.000115  0.000224  0.000162  0.000160
# 3  0.000127  0.000235  0.000185  0.000136  0.000181  0.000186  0.000086
# 4  0.000143  0.000255  0.000192  0.000163  0.000186  0.000180  0.000139
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000219  0.000334  0.000174  ...  0.000353  0.000278  0.000041  0.000074
# 1  0.000202  0.000302  0.000126  ...  0.000426  0.000203 -0.000008  0.000069
# 2  0.000169  0.000362  0.000138  ...  0.000365  0.000247 -0.000006  0.000046
# 3  0.000173  0.000304  0.000163  ...  0.000376  0.000212  0.000003  0.000092
# 4  0.000149  0.000354  0.000155  ...  0.000392  0.000241  0.000023  0.000051
#
#          x7        y7        z7        x8        y8        z8
# ...

# %% [markdown]
# # Graficos

# %% [markdown]
# ### Distribuciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = 24


for columna in range(columnas):
        ax = sns.histplot(data=base_1.iloc[:,columna], kde=True, color = 'green')
        ax = sns.histplot(data=base_1x.iloc[:,columna], kde=True, color = 'blue')
        ax = sns.histplot(data=base_2x.iloc[:,columna], kde=True, color = 'yellow')
        ax = sns.histplot(data=base_3x.iloc[:,columna], kde=True, color = 'red')
        
        print('Sensor: '+str(columna+1))
        plt.grid(True)
        plt.show()
# Out:
# Sensor: 1
# Sensor: 2
# Sensor: 3
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Sensor: 4
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import numpy as np

# %%
df_new = pd.concat([base_1, base_1x, base_2x, base_3x], ignore_index=True)

# %%
df1_corr = df_new.corr()

mask = np.triu(np.ones_like(df1_corr, dtype=np.bool))

mask = mask[1:, :-1]
corr = df1_corr.iloc[1:,:-1].copy()

cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, vmin=-1, vmax=1, square=True)
#plt.savefig('Hb.png')
# Out:
# <AxesSubplot:>

# %%
hb = df_new.transpose()

from scipy.cluster.hierarchy import dendrogram, linkage
#sample1 = hb.sample(n = 10000)
#sample1.head()

Z = linkage(hb, 'ward')

plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')
#plt.savefig('HB.jpg')

# %% [markdown]
# ## Por amplitudes

# %% [markdown]
# #### 1

# %%
sampleo = '/home/bryan/Escritorio/PyOD/Dataset/'
dataset = Ficheros(path_csv, '.csv')

prueba_1 = []
prueba_2 = []
prueba_3 = []

for archivo in dataset:
    if archivo.startswith('1_1_1'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_2_1'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_3_1'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_4_1'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_5_1'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_6_1'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_7_1'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_8_1'):
        prueba_2.append(archivo)
    
    elif archivo.startswith('1_9_1'):
        prueba_3.append(archivo)
        

    

prueba_1.sort()
prueba_2.sort()
prueba_3.sort()

# %%
prueba_1
# Out:
# ['1_1_1A.csv',
#  '1_2_1A.csv',
#  '1_3_1A.csv',
#  '1_4_1A.csv',
#  '1_5_1A.csv',
#  '1_6_1A.csv',
#  '1_7_1A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1 = dataframe_chipeado(prueba_1)

base_2 = dataframe_chipeado(prueba_2)

base_3 = dataframe_chipeado(prueba_3)

# %%
base_1.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000348  0.000213  0.000172  0.000219  0.000228  0.000197  0.000105
# 1  0.000145  0.000322  0.000229  0.000266  0.000294  0.000237  0.000158
# 2  0.000116  0.000198  0.000208  0.000177  0.000195  0.000106  0.000091
# 3  0.000034  0.000314  0.000184  0.000061  0.000118  0.000130  0.000115
# 4  0.000244  0.000287  0.000177  0.000135  0.000219  0.000266  0.000145
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000171  0.000310  0.000068  ...  0.000368  0.000273  0.000018  0.000030
# 1  0.000210  0.000323  0.000177  ...  0.000372  0.000152  0.000021  0.000068
# 2  0.000210  0.000316  0.000153  ...  0.000300  0.000227  0.000020  0.000082
# 3  0.000169  0.000278  0.000213  ...  0.000419  0.000157  0.000024  0.000080
# 4  0.000218  0.000279  0.000119  ...  0.000369  0.000200  0.000016  0.000068
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
base_2.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000341  0.000216  0.000202  0.000177  0.000214  0.000177  0.000078
# 1  0.000106  0.000238  0.000216  0.000128  0.000164  0.000088  0.000104
# 2  0.000150  0.000240  0.000309  0.000226  0.000253  0.000160  0.000063
# 3 -0.000011  0.000297  0.000166  0.000066  0.000153  0.000130  0.000122
# 4  0.000208  0.000300  0.000193  0.000127  0.000234  0.000253  0.000128
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000213  0.000329  0.000098  ...  0.000388  0.000297  0.000089  0.000050
# 1  0.000238  0.000398  0.000155  ...  0.000376  0.000164 -0.000017  0.000069
# 2  0.000204  0.000369  0.000098  ...  0.000419  0.000280  0.000032  0.000099
# 3  0.000157  0.000294  0.000216  ...  0.000386  0.000189  0.000017  0.000055
# 4  0.000194  0.000276  0.000099  ...  0.000339  0.000157  0.000023  0.000003
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
base_3.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000152  0.000279  0.000139  0.000108  0.000126  0.000211  0.000085
# 1  0.000125  0.000272  0.000233  0.000086  0.000155  0.000191  0.000097
# 2  0.000100  0.000215  0.000232  0.000231  0.000209  0.000088  0.000157
# 3  0.000182  0.000230  0.000233  0.000191  0.000191  0.000167  0.000082
# 4  0.000180  0.000265  0.000209  0.000149  0.000253  0.000145  0.000107
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000185  0.000287  0.000151  ...  0.000345  0.000325  0.000036  0.000062
# 1  0.000147  0.000289  0.000168  ...  0.000394  0.000076  0.000069  0.000094
# 2  0.000235  0.000340  0.000106  ...  0.000383  0.000291  0.000052  0.000050
# 3  0.000180  0.000346  0.000113  ...  0.000351  0.000191  0.000060  0.000061
# 4  0.000222  0.000290  0.000121  ...  0.000414  0.000264  0.000019  0.000064
#
#          x7        y7        z7        x8        y8            z8
# ...

# %%
len(base_1), len(base_2), len(base_3)
# Out:
# (115619, 16517, 16517)

# %%
#sampleo2 = '/home/bryan/Escritorio/Paper/Sampleo Final/'

# %%
#base_1.to_csv(sampleo2 + 'TRAINx05.csv')

# %%
prueba_1x = []
prueba_2x = []
prueba_3x = []

for archivo in dataset:
    if archivo.startswith('2_'):
        prueba_1x.append(archivo)
        
    elif archivo.startswith('3_'):
        prueba_2x.append(archivo)
    
    elif archivo.startswith('4_'):
        prueba_3x.append(archivo)

    
prueba_1x.sort()
prueba_2x.sort()
prueba_3x.sort()

# %%
prueba_1x
# Out:
# ['2_1_05A.csv',
#  '2_1_1A.csv',
#  '2_1_2A.csv',
#  '2_1_3A.csv',
#  '2_2_05A.csv',
#  '2_2_1A.csv',
#  '2_2_2A.csv',
#  '2_2_3A.csv',
#  '2_3_05A.csv',
#  '2_3_1A.csv',
#  '2_3_2A.csv',
#  '2_3_3A.csv',
#  '2_4_05A.csv',
#  '2_4_1A.csv',
#  '2_4_2A.csv',
#  '2_4_3A.csv',
#  '2_5_05A.csv',
#  '2_5_1A.csv',
#  '2_5_2A.csv',
#  '2_5_3A.csv']

# %%
prueba_1xx = []
prueba_2xx = []
prueba_3xx = []

for archivo in prueba_1x:
    if archivo.endswith('1A.csv'):
        prueba_1xx.append(archivo)

for archivo in prueba_2x:
    if archivo.endswith('1A.csv'):
        prueba_2xx.append(archivo)
        
        
for archivo in prueba_3x:
    if archivo.endswith('1A.csv'):
        prueba_3xx.append(archivo)

# %%
prueba_1xx
# Out:
# ['2_1_1A.csv', '2_2_1A.csv', '2_3_1A.csv', '2_4_1A.csv', '2_5_1A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1x = dataframe_chipeado(prueba_1xx)

base_2x = dataframe_chipeado(prueba_2xx)

base_3x = dataframe_chipeado(prueba_3xx)

# %%
base_1x.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000091  0.000315  0.000244  0.000128  0.000133  0.000165  0.000151
# 1  0.000083  0.000213  0.000259  0.000263  0.000223  0.000109  0.000090
# 2  0.000151  0.000186  0.000219  0.000249  0.000188  0.000125  0.000054
# 3  0.000189  0.000330  0.000193  0.000168  0.000241  0.000209  0.000124
# 4  0.000281  0.000267  0.000213  0.000005  0.000123  0.000194  0.000128
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000164  0.000323  0.000123  ...  0.000378  0.000122  0.000049  0.000034
# 1  0.000220  0.000367  0.000151  ...  0.000418  0.000341 -0.000004  0.000071
# 2  0.000183  0.000339  0.000090  ...  0.000358  0.000174  0.000044  0.000047
# 3  0.000229  0.000308  0.000146  ...  0.000444  0.000282  0.000033  0.000100
# 4  0.000132  0.000329  0.000123  ...  0.000377  0.000173  0.000029  0.000031
#
#          x7        y7        z7        x8        y8        z8
# ...

# %% [markdown]
# # Graficos

# %% [markdown]
# ### Distribuciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = 24


for columna in range(columnas):
        ax = sns.histplot(data=base_1.iloc[:,columna], kde=True, color = 'green')
        ax = sns.histplot(data=base_1x.iloc[:,columna], kde=True, color = 'blue')
        ax = sns.histplot(data=base_2x.iloc[:,columna], kde=True, color = 'yellow')
        ax = sns.histplot(data=base_3x.iloc[:,columna], kde=True, color = 'red')
        
        print('Sensor: '+str(columna+1))
        plt.grid(True)
        plt.show()
# Out:
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Sensor: 1
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import numpy as np

# %%
df_new = pd.concat([base_1, base_1x, base_2x, base_3x], ignore_index=True)

# %%
df1_corr = df_new.corr()

mask = np.triu(np.ones_like(df1_corr, dtype=np.bool))

mask = mask[1:, :-1]
corr = df1_corr.iloc[1:,:-1].copy()

cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, vmin=-1, vmax=1, square=True)
#plt.savefig('Hb.png')
# Out:
# <AxesSubplot:>

# %%
hb = df_new.transpose()

from scipy.cluster.hierarchy import dendrogram, linkage
#sample1 = hb.sample(n = 10000)
#sample1.head()

Z = linkage(hb, 'ward')

plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')
#plt.savefig('HB.jpg')

# %% [markdown]
# ## Por amplitudes

# %% [markdown]
# #### 2

# %%
sampleo = '/home/bryan/Escritorio/PyOD/Dataset/'
dataset = Ficheros(path_csv, '.csv')

prueba_1 = []
prueba_2 = []
prueba_3 = []

for archivo in dataset:
    if archivo.startswith('1_1_2'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_2_2'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_3_2'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_4_2'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_5_2'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_6_2'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_7_2'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_8_2'):
        prueba_2.append(archivo)
    
    elif archivo.startswith('1_9_2'):
        prueba_3.append(archivo)
        

    

prueba_1.sort()
prueba_2.sort()
prueba_3.sort()

# %%
prueba_1
# Out:
# ['1_1_2A.csv',
#  '1_2_2A.csv',
#  '1_3_2A.csv',
#  '1_4_2A.csv',
#  '1_5_2A.csv',
#  '1_6_2A.csv',
#  '1_7_2A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1 = dataframe_chipeado(prueba_1)

base_2 = dataframe_chipeado(prueba_2)

base_3 = dataframe_chipeado(prueba_3)

# %%
base_1.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000182  0.000457  0.000271  0.000124  0.000323  0.000191  0.000152
# 1  0.000249  0.000152  0.000230 -0.000011  0.000070  0.000212 -0.000032
# 2  0.000382  0.000496  0.000263  0.000080  0.000305  0.000287  0.000150
# 3  0.000235  0.000194  0.000265  0.000248  0.000134  0.000171  0.000035
# 4  0.000042  0.000285  0.000223  0.000279  0.000163  0.000027  0.000199
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000191  0.000226 -0.000017  ...  0.000374  0.000116  0.000078  0.000098
# 1  0.000187  0.000325  0.000241  ...  0.000400  0.000403 -0.000024  0.000027
# 2  0.000171  0.000296  0.000165  ...  0.000333  0.000014  0.000095  0.000100
# 3  0.000229  0.000412  0.000196  ...  0.000411  0.000417 -0.000030  0.000099
# 4  0.000164  0.000275  0.000108  ...  0.000343  0.000027  0.000080  0.000109
#
#          x7            y7        z7        x8        y8        z8
# ...

# %%
base_2.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0 -0.000160  0.000264  0.000351  0.000199  0.000115 -0.000020  0.000094
# 1  0.000074  0.000120  0.000274  0.000185  0.000159  0.000164  0.000143
# 2  0.000669  0.000393  0.000248  0.000129  0.000165  0.000228  0.000035
# 3  0.000412  0.000221  0.000139 -0.000104  0.000061  0.000224  0.000108
# 4  0.000391  0.000534  0.000492  0.000199  0.000322  0.000231  0.000065
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000086  0.000352  0.000156  ...  0.000445  0.000204  0.000034  0.000121
# 1  0.000269  0.000345  0.000179  ...  0.000364  0.000204 -0.000045  0.000061
# 2  0.000039  0.000295  0.000071  ...  0.000404  0.000212  0.000082  0.000037
# 3  0.000280  0.000299  0.000184  ...  0.000362  0.000150 -0.000028  0.000015
# 4  0.000119  0.000310  0.000129  ...  0.000401  0.000348  0.000111  0.000135
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
base_3.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000205  0.000190  0.000172  0.000005  0.000087  0.000183  0.000009
# 1  0.000408  0.000568  0.000193  0.000044  0.000284  0.000306  0.000143
# 2  0.000279  0.000140  0.000110  0.000182  0.000108  0.000211  0.000059
# 3  0.000072  0.000362  0.000270  0.000224  0.000162  0.000041  0.000232
# 4 -0.000123  0.000013  0.000248  0.000305  0.000200  0.000115  0.000125
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000215  0.000382  0.000226  ...  0.000373  0.000424 -0.000064  0.000049
# 1  0.000168  0.000246  0.000127  ...  0.000358  0.000011  0.000110  0.000083
# 2  0.000236  0.000393  0.000229  ...  0.000376  0.000447 -0.000076  0.000062
# 3  0.000108  0.000279  0.000040  ...  0.000353 -0.000002  0.000100  0.000084
# 4  0.000206  0.000387  0.000084  ...  0.000416  0.000411 -0.000073  0.000100
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
len(base_1), len(base_2), len(base_3)
# Out:
# (115619, 16517, 16517)

# %%
#sampleo2 = '/home/bryan/Escritorio/Paper/Sampleo Final/'

# %%
#base_1.to_csv(sampleo2 + 'TRAINx05.csv')

# %%
prueba_1x = []
prueba_2x = []
prueba_3x = []

for archivo in dataset:
    if archivo.startswith('2_'):
        prueba_1x.append(archivo)
        
    elif archivo.startswith('3_'):
        prueba_2x.append(archivo)
    
    elif archivo.startswith('4_'):
        prueba_3x.append(archivo)

    
prueba_1x.sort()
prueba_2x.sort()
prueba_3x.sort()

# %%
prueba_1x
# Out:
# ['2_1_05A.csv',
#  '2_1_1A.csv',
#  '2_1_2A.csv',
#  '2_1_3A.csv',
#  '2_2_05A.csv',
#  '2_2_1A.csv',
#  '2_2_2A.csv',
#  '2_2_3A.csv',
#  '2_3_05A.csv',
#  '2_3_1A.csv',
#  '2_3_2A.csv',
#  '2_3_3A.csv',
#  '2_4_05A.csv',
#  '2_4_1A.csv',
#  '2_4_2A.csv',
#  '2_4_3A.csv',
#  '2_5_05A.csv',
#  '2_5_1A.csv',
#  '2_5_2A.csv',
#  '2_5_3A.csv']

# %%
prueba_1xx = []
prueba_2xx = []
prueba_3xx = []

for archivo in prueba_1x:
    if archivo.endswith('2A.csv'):
        prueba_1xx.append(archivo)

for archivo in prueba_2x:
    if archivo.endswith('2A.csv'):
        prueba_2xx.append(archivo)
        
        
for archivo in prueba_3x:
    if archivo.endswith('2A.csv'):
        prueba_3xx.append(archivo)

# %%
prueba_1xx
# Out:
# ['2_1_2A.csv', '2_2_2A.csv', '2_3_2A.csv', '2_4_2A.csv', '2_5_2A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1x = dataframe_chipeado(prueba_1xx)

base_2x = dataframe_chipeado(prueba_2xx)

base_3x = dataframe_chipeado(prueba_3xx)

# %%
base_1x.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000355  0.000146  0.000121 -0.000051  0.000056  0.000194  0.000148
# 1  0.000381  0.000427  0.000296  0.000122  0.000299  0.000188  0.000057
# 2 -0.000190  0.000276  0.000156  0.000102  0.000138  0.000186  0.000133
# 3 -0.000054  0.000296  0.000143  0.000246  0.000251  0.000049  0.000108
# 4  0.000022  0.000166  0.000063  0.000119  0.000144  0.000146  0.000099
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000252  0.000287  0.000166  ...  0.000383  0.000238 -0.000084  0.000068
# 1  0.000121  0.000329  0.000104  ...  0.000428  0.000291  0.000160  0.000079
# 2  0.000255  0.000318  0.000178  ...  0.000447  0.000232 -0.000010  0.000171
# 3  0.000230  0.000303  0.000176  ...  0.000395  0.000246  0.000091  0.000080
# 4  0.000232  0.000314  0.000162  ...  0.000372  0.000085 -0.000031  0.000066
#
#          x7        y7        z7        x8        y8        z8
# ...

# %% [markdown]
# # Graficos

# %% [markdown]
# ### Distribuciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = 24


for columna in range(columnas):
        ax = sns.histplot(data=base_1.iloc[:,columna], kde=True, color = 'green')
        ax = sns.histplot(data=base_1x.iloc[:,columna], kde=True, color = 'blue')
        ax = sns.histplot(data=base_2x.iloc[:,columna], kde=True, color = 'yellow')
        ax = sns.histplot(data=base_3x.iloc[:,columna], kde=True, color = 'red')
        
        print('Sensor: '+str(columna+1))
        plt.grid(True)
        plt.show()
# Out:
# Sensor: 1
# Sensor: 2
# Sensor: 3
# Sensor: 4
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Sensor: 5
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import numpy as np

# %%
df_new = pd.concat([base_1, base_1x, base_2x, base_3x], ignore_index=True)

# %%
df1_corr = df_new.corr()

mask = np.triu(np.ones_like(df1_corr, dtype=np.bool))

mask = mask[1:, :-1]
corr = df1_corr.iloc[1:,:-1].copy()

cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, vmin=-1, vmax=1, square=True)
#plt.savefig('Hb.png')
# Out:
# <AxesSubplot:>

# %%
hb = df_new.transpose()

from scipy.cluster.hierarchy import dendrogram, linkage
#sample1 = hb.sample(n = 10000)
#sample1.head()

Z = linkage(hb, 'ward')

plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')
#plt.savefig('HB.jpg')

# %% [markdown]
# ## Por amplitudes

# %% [markdown]
# #### 3

# %%
sampleo = '/home/bryan/Escritorio/PyOD/Dataset/'
dataset = Ficheros(path_csv, '.csv')

prueba_1 = []
prueba_2 = []
prueba_3 = []

for archivo in dataset:
    if archivo.startswith('1_1_3'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_2_3'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_3_3'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_4_3'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_5_3'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_6_3'):
        prueba_1.append(archivo)
    
    elif archivo.startswith('1_7_3'):
        prueba_1.append(archivo)
        
    elif archivo.startswith('1_8_3'):
        prueba_2.append(archivo)
    
    elif archivo.startswith('1_9_3'):
        prueba_3.append(archivo)
        

    

prueba_1.sort()
prueba_2.sort()
prueba_3.sort()

# %%
prueba_1
# Out:
# ['1_1_3A.csv',
#  '1_2_3A.csv',
#  '1_3_3A.csv',
#  '1_4_3A.csv',
#  '1_5_3A.csv',
#  '1_6_3A.csv',
#  '1_7_3A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1 = dataframe_chipeado(prueba_1)

base_2 = dataframe_chipeado(prueba_2)

base_3 = dataframe_chipeado(prueba_3)

# %%
base_1.head()
# Out:
#              x1        y1        z1        x2        y2        z2        x3  \
# 0  2.539200e-07  0.000232  0.000066  0.000146  0.000267  0.000198  0.000101
# 1  1.083230e-04  0.000478  0.000353  0.000160  0.000267  0.000137  0.000002
# 2  6.863664e-05  0.000450  0.000493  0.000310  0.000333  0.000182  0.000055
# 3  1.119864e-04  0.000312  0.000180 -0.000067  0.000120  0.000202  0.000187
# 4  1.083230e-04  0.000181 -0.000006  0.000177  0.000281  0.000349  0.000163
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000356  0.000381  0.000091  ...  0.000450  0.000321 -0.000071  0.000146
# 1  0.000118  0.000334  0.000185  ...  0.000427  0.000195  0.000085  0.000066
# 2  0.000243  0.000347  0.000247  ...  0.000424  0.000121 -0.000014  0.000054
# 3  0.000118  0.000343  0.000199  ...  0.000481  0.000212  0.000051  0.000043
# 4  0.000183  0.000324  0.000196  ...  0.000315  0.000211  0.000054  0.000012
#
# ...

# %%
base_2.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000081  0.000112  0.000528 -0.000034  0.000139  0.000061  0.000193
# 1  0.000216 -0.000216  0.000113  0.000022  0.000002  0.000111  0.000046
# 2  0.000307  0.000483  0.000045  0.000132  0.000322  0.000258  0.000177
# 3  0.000332  0.000308  0.000039  0.000063  0.000194  0.000087  0.000062
# 4  0.000138  0.000510  0.000075  0.000364  0.000361  0.000278  0.000125
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000178  0.000239 -0.000034  ...  0.000375  0.000110 -0.000126  0.000066
# 1  0.000189  0.000360  0.000233  ...  0.000433  0.000552  0.000054  0.000117
# 2  0.000286  0.000273  0.000217  ...  0.000414  0.000100 -0.000022  0.000130
# 3  0.000180  0.000304  0.000263  ...  0.000353  0.000154  0.000077  0.000059
# 4  0.000264  0.000415  0.000066  ...  0.000375  0.000084 -0.000022  0.000061
#
#          x7        y7        z7        x8        y8        z8
# ...

# %%
base_3.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000359  0.000654  0.000227  0.000279  0.000497  0.000317  0.000079
# 1  0.000152  0.000341  0.000204  0.000108  0.000239  0.000082  0.000045
# 2  0.000028  0.000588  0.000509  0.000369  0.000467  0.000172  0.000070
# 3 -0.000099  0.000205  0.000204 -0.000051  0.000117  0.000145  0.000184
# 4  0.000045  0.000107 -0.000159  0.000046  0.000054  0.000170  0.000056
#
#          y3        z3        x4  ...        z5        x6            y6  \
# 0  0.000411  0.000357  0.000141  ...  0.000436  0.000538  2.709849e-05
# 1  0.000141  0.000324  0.000154  ...  0.000451  0.000205  4.173703e-05
# 2  0.000341  0.000365  0.000397  ...  0.000379  0.000202 -1.559724e-05
# 3  0.000131  0.000287  0.000060  ...  0.000415 -0.000070 -9.587000e-07
# 4  0.000176  0.000284  0.000024  ...  0.000330  0.000163  6.970507e-06
#
#          z6        x7        y7        z7        x8        y8        z8
# ...

# %%
len(base_1), len(base_2), len(base_3)
# Out:
# (115619, 16517, 16517)

# %%
#sampleo2 = '/home/bryan/Escritorio/Paper/Sampleo Final/'

# %%
#base_1.to_csv(sampleo2 + 'TRAINx05.csv')

# %%
prueba_1x = []
prueba_2x = []
prueba_3x = []

for archivo in dataset:
    if archivo.startswith('2_'):
        prueba_1x.append(archivo)
        
    elif archivo.startswith('3_'):
        prueba_2x.append(archivo)
    
    elif archivo.startswith('4_'):
        prueba_3x.append(archivo)

    
prueba_1x.sort()
prueba_2x.sort()
prueba_3x.sort()

# %%
prueba_1x
# Out:
# ['2_1_05A.csv',
#  '2_1_1A.csv',
#  '2_1_2A.csv',
#  '2_1_3A.csv',
#  '2_2_05A.csv',
#  '2_2_1A.csv',
#  '2_2_2A.csv',
#  '2_2_3A.csv',
#  '2_3_05A.csv',
#  '2_3_1A.csv',
#  '2_3_2A.csv',
#  '2_3_3A.csv',
#  '2_4_05A.csv',
#  '2_4_1A.csv',
#  '2_4_2A.csv',
#  '2_4_3A.csv',
#  '2_5_05A.csv',
#  '2_5_1A.csv',
#  '2_5_2A.csv',
#  '2_5_3A.csv']

# %%
prueba_1xx = []
prueba_2xx = []
prueba_3xx = []

for archivo in prueba_1x:
    if archivo.endswith('3A.csv'):
        prueba_1xx.append(archivo)

for archivo in prueba_2x:
    if archivo.endswith('3A.csv'):
        prueba_2xx.append(archivo)
        
        
for archivo in prueba_3x:
    if archivo.endswith('3A.csv'):
        prueba_3xx.append(archivo)

# %%
prueba_1xx
# Out:
# ['2_1_3A.csv', '2_2_3A.csv', '2_3_3A.csv', '2_4_3A.csv', '2_5_3A.csv']

# %%
def dataframe_chipeado(lista):
    df_HB={}
    prueba = columns()
    df_HB = pd.DataFrame(df_HB)
    for csv in range(len(lista)):
        df_t = pd.read_csv(sampleo+ lista[csv])
        a1 = df_t.iloc[:, 1:25]
        df_HB= pd.concat([df_HB, a1], ignore_index=True)
        
    df_HB.columns = prueba
    
    return df_HB

base_1x = dataframe_chipeado(prueba_1xx)

base_2x = dataframe_chipeado(prueba_2xx)

base_3x = dataframe_chipeado(prueba_3xx)

# %%
base_1x.head()
# Out:
#          x1        y1        z1        x2        y2        z2        x3  \
# 0  0.000156  0.000354  0.000144  0.000251  0.000330  0.000132  0.000028
# 1  0.000195  0.000448  0.000495  0.000116  0.000345  0.000230  0.000155
# 2 -0.000025  0.000342  0.000516  0.000211  0.000302  0.000097 -0.000038
# 3  0.000117  0.000254  0.000152  0.000024  0.000149  0.000202  0.000145
# 4  0.000178  0.000309 -0.000025  0.000114  0.000147  0.000301  0.000153
#
#          y3        z3        x4  ...        z5        x6        y6        z6  \
# 0  0.000369  0.000375  0.000135  ...  0.000415  0.000584 -0.000074  0.000255
# 1  0.000124  0.000342  0.000065  ...  0.000422  0.000177  0.000106  0.000136
# 2  0.000279  0.000300  0.000268  ...  0.000312  0.000276 -0.000172  0.000066
# 3  0.000119  0.000323  0.000256  ...  0.000346  0.000088  0.000058 -0.000053
# 4  0.000255  0.000276  0.000198  ...  0.000377  0.000150  0.000004  0.000036
#
#          x7        y7        z7        x8        y8        z8
# ...

# %% [markdown]
# # Graficos

# %% [markdown]
# ### Distribuciones

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columnas = 24


for columna in range(columnas):
        ax = sns.histplot(data=base_1.iloc[:,columna], kde=True, color = 'green')
        ax = sns.histplot(data=base_1x.iloc[:,columna], kde=True, color = 'blue')
        ax = sns.histplot(data=base_2x.iloc[:,columna], kde=True, color = 'yellow')
        ax = sns.histplot(data=base_3x.iloc[:,columna], kde=True, color = 'red')
        
        print('Sensor: '+str(columna+1))
        plt.grid(True)
        plt.show()
# Out:
# Sensor: 1
# Sensor: 2
# Sensor: 3
# Sensor: 4
# Sensor: 5
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# Sensor: 6
# /home/bryan/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import numpy as np

# %%
df_new = pd.concat([base_1, base_1x, base_2x, base_3x], ignore_index=True)

# %%
df1_corr = df_new.corr()

mask = np.triu(np.ones_like(df1_corr, dtype=np.bool))

mask = mask[1:, :-1]
corr = df1_corr.iloc[1:,:-1].copy()

cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

fig, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, vmin=-1, vmax=1, square=True)
#plt.savefig('Hb.png')
# Out:
# <AxesSubplot:>

# %%
hb = df_new.transpose()

from scipy.cluster.hierarchy import dendrogram, linkage
#sample1 = hb.sample(n = 10000)
#sample1.head()

Z = linkage(hb, 'ward')

plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')
#plt.savefig('HB.jpg')
